# %%
pip install pandas pnadium numpy pyarrow matplotlib openpyxl
# Out:
# Requirement already satisfied: pandas in c:\users\lucas\appdata\local\programs\python\python314\lib\site-packages (3.0.1)
# Requirement already satisfied: pnadium in c:\users\lucas\appdata\local\programs\python\python314\lib\site-packages (0.24)
# Requirement already satisfied: numpy in c:\users\lucas\appdata\local\programs\python\python314\lib\site-packages (2.4.3)
# Requirement already satisfied: pyarrow in c:\users\lucas\appdata\local\programs\python\python314\lib\site-packages (23.0.1)
# Requirement already satisfied: matplotlib in c:\users\lucas\appdata\local\programs\python\python314\lib\site-packages (3.10.8)
# Requirement already satisfied: openpyxl in c:\users\lucas\appdata\local\programs\python\python314\lib\site-packages (3.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lucas\appdata\roaming\python\python314\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\lucas\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: unidecode in c:\users\lucas\appdata\local\programs\python\python314\lib\site-packages (from pnadium) (1.4.0)
# Requirement already satisfied: appdirs in c:\users\lucas\appdata\local\programs\python\python314\lib\site-packages (from pnadium) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lucas\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\lucas\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lucas\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\lucas\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\lucas\appdata\roaming\python\python314\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in c:\users\lucas\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\users\lucas\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: et-xmlfile in c:\users\lucas\appdata\local\programs\python\python314\lib\site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: six>=1.5 in c:\users\lucas\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import pyarrow
import pnadium
import matplotlib
import openpyxl
import numpy

# %%
df_sisagua = pd.read_csv("vigilancia_parametros_basicos_2021.csv", sep=';', encoding='latin1', low_memory=False)
display(df_sisagua)
display(df_sisagua.shape)
display(df_sisagua.info())
display(df_sisagua.describe())
# Out:
#         NO_REGIAO SG_UF                     NO_REGIONAL  \
# 0             SUL    RS                          1ª CRS
# 1             SUL    RS                          1ª CRS
# 2             SUL    RS                          1ª CRS
# 3             SUL    RS                          1ª CRS
# 4             SUL    RS                         15ª CRS
# ...           ...   ...                             ...
# 2897029  NORDESTE    CE  06 REGIONAL DE SAUDE ITAPIPOCA
# 2897030  NORDESTE    PB   09 GERENCIA REGIONAL DE SAUDE
# 2897031     NORTE    PA                          5° CRS
# 2897032       SUL    PR               14 RS - PARANAVAI
# 2897033  NORDESTE    CE   22 REGIONAL DE SAUDE CASCAVEL
#
#                         NO_MUNICIPIO  CO_MUNICIPIO_IBGE    NU_AMOSTRA  \
# 0                         MONTENEGRO             431240  213216000207
# 1                         MONTENEGRO             431240  213216000184
# 2                         MONTENEGRO             431240  213216000104
# 3                         MONTENEGRO             431240  213216000134
# 4                           RONDINHA             431620  214520000021
# ...                              ...                ...           ...
# 2897029                     AMONTADA             230075  210610000029
# 2897030           BERNARDINO BATISTA             250205  210906000031
# 2897031                 CAPITAO POCO             150230  210515000350
# 2897032  SANTA CRUZ DE MONTE CASTELO             412330  211424000088
# 2897033                     BEBERIBE             230220  210706000444
#
#         TP_MOTIVO_COLETA TP_ABASTECIMENTO NU_SOLUCAO_ABASTECIMENTO  \
# 0                 Rotina              SAC            C431240000008
# 1                 Rotina              SAC            C431240000008
# 2                 Rotina              SAC            C431240000008
# 3                 Rotina              SAC            C431240000008
# 4                 Rotina              SAC            C431620000005
# ...                  ...              ...                      ...
# 2897029           Rotina              SAI            I230075000082
# 2897030           Rotina              SAI            I250205000008
# 2897031           Rotina              SAI            I150230000370
# 2897032           Rotina              SAI            I412330000001
# 2897033           Rotina              SAI            I230220000012
#
#                            NO_SOLUCAO_ABASTECIMENTO  ...  \
# 0                                       SAC SOBRADO  ...
# 1                                       SAC SOBRADO  ...
# 2                                       SAC SOBRADO  ...
# 3                                       SAC SOBRADO  ...
# 4        LINHA ARAÇÁ SANTO ANTONIO (FIORELO) SAC 25  ...
# ...                                             ...  ...
# 2897029                    SITIO CARIRI DOS IRINEUS  ...
# 2897030    CACIMBAO DE JOCA TOMAZ ST COSME DE BRITO  ...
# 2897031                     CASA DO EVERTON SANTANA  ...
# 2897032           ASSENTAMENTO 17 DE ABRILQUERENCIA  ...
# 2897033                               BAIRRO CENTRO  ...
#
#                                          NO_LOCAL  NU_LATITUDE  NU_LONGITUDE  \
# 0                                             NaN          NaN           NaN
# 1                                             NaN          NaN           NaN
# 2                                             NaN          NaN           NaN
# 3                                             NaN          NaN           NaN
# 4        LINHA ARACA SANTO ANTONIO FIORELO SAC 25          NaN           NaN
# ...                                           ...          ...           ...
# 2897029                                       NaN          NaN           NaN
# 2897030                                       NaN          NaN           NaN
# 2897031                                       NaN          NaN           NaN
# 2897032                                       NaN          NaN           NaN
# 2897033                                       NaN          NaN           NaN
#
#                            PARAMETRO ANALISE_REALIZADA DT_ANALISE  LD  LQ  \
# 0                    Fluoreto (mg/L)               NaN        NaN NaN NaN
# 1                    Fluoreto (mg/L)               NaN        NaN NaN NaN
# 2        Cloro residual livre (mg/L)          EM_CAMPO        NaN NaN NaN
# 3                      Turbidez (uT)    EM_LABORATORIO        NaN NaN NaN
# 4                      Turbidez (uT)    EM_LABORATORIO        NaN NaN NaN
# ...                              ...               ...        ...  ..  ..
# 2897029            Coliformes totais               NaN        NaN NaN NaN
# 2897030            Coliformes totais               NaN        NaN NaN NaN
# 2897031             Escherichia coli               NaN        NaN NaN NaN
# 2897032            Coliformes totais               NaN        NaN NaN NaN
# 2897033            Coliformes totais               NaN        NaN NaN NaN
#
#         RESULTADO PROVIDENCIA
# 0            0,05         NaN
# 1            0,05         NaN
# 2            1,08         NaN
# 3             0,7         NaN
# 4             0,3         NaN
# ...           ...         ...
# 2897029   AUSENTE         NaN
# 2897030  PRESENTE         NaN
# 2897031   AUSENTE         NaN
# 2897032  PRESENTE         NaN
# 2897033  PRESENTE         NaN
#
# [2897034 rows x 34 columns]
# (2897034, 34)
# <class 'pandas.DataFrame'>
# RangeIndex: 2897034 entries, 0 to 2897033
# Data columns (total 34 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   NO_REGIAO                 str
#  1   SG_UF                     str
#  2   NO_REGIONAL               str
#  3   NO_MUNICIPIO              str
#  4   CO_MUNICIPIO_IBGE         int64
#  5   NU_AMOSTRA                str
#  6   TP_MOTIVO_COLETA          str
#  7   TP_ABASTECIMENTO          str
#  8   NU_SOLUCAO_ABASTECIMENTO  str
#  9   NO_SOLUCAO_ABASTECIMENTO  str
#  10  NO_ETA                    str
#  11  NU_ANO                    int64
#  12  NU_MES                    int64
#  13  DT_COLETA                 str
#  14  HR_COLETA                 str
#  15  DT_LAUDO                  str
#  16  DT_INCLUSAO_REGISTRO      str
#  17  TP_PROCEDENCIA_COLETA     str
#  18  TP_PONTO_COLETA           str
#  19  DS_LOCAL                  str
#  20  TP_ZONA                   str
#  21  NO_CATEGORIA_AREA         str
#  22  NO_AREA                   str
#  23  TP_LOCAL                  str
#  24  NO_LOCAL                  str
#  25  NU_LATITUDE               float64
#  26  NU_LONGITUDE              float64
#  27  PARAMETRO                 str
#  28  ANALISE_REALIZADA         str
#  29  DT_ANALISE                float64
#  30  LD                        float64
#  31  LQ                        float64
#  32  RESULTADO                 str
#  33  PROVIDENCIA               str
# dtypes: float64(5), int64(3), str(26)
# memory usage: 1.6 GB
# None
#        CO_MUNICIPIO_IBGE     NU_ANO        NU_MES    NU_LATITUDE  \
# count       2.897034e+06  2897034.0  2.897034e+06  212536.000000
# mean        3.314818e+05     2021.0  6.621375e+00     -16.469967
# std         9.554270e+04        0.0  3.331610e+00       7.912316
# min         1.100010e+05     2021.0  1.000000e+00     -32.558450
# 25%         2.610700e+05     2021.0  4.000000e+00     -22.309833
# 50%         3.303100e+05     2021.0  7.000000e+00     -16.575240
# 75%         4.121800e+05     2021.0  9.000000e+00     -10.856850
# max         5.300310e+05     2021.0  1.200000e+01       1.763430
#
#         NU_LONGITUDE  DT_ANALISE   LD   LQ
# count  212536.000000         0.0  0.0  0.0
# mean      -47.001642         NaN  NaN  NaN
# std         6.748151         NaN  NaN  NaN
# min       -69.944019         NaN  NaN  NaN
# 25%       -52.021036         NaN  NaN  NaN
# 50%       -49.000000         NaN  NaN  NaN
# 75%       -39.733740         NaN  NaN  NaN
# max         0.000000         NaN  NaN  NaN

# %%
df_sisagua['CO_MUNICIPIO_IBGE'] = df_sisagua['CO_MUNICIPIO_IBGE'].astype(str)

# %%
df_sisagua[df_sisagua['NU_AMOSTRA'] == '213216000207']
# Out:
#         NO_REGIAO SG_UF NO_REGIONAL NO_MUNICIPIO CO_MUNICIPIO_IBGE  \
# 0             SUL    RS      1ª CRS   MONTENEGRO            431240
# 417959        SUL    RS      1ª CRS   MONTENEGRO            431240
# 1464347       SUL    RS      1ª CRS   MONTENEGRO            431240
# 1809511       SUL    RS      1ª CRS   MONTENEGRO            431240
# 2350895       SUL    RS      1ª CRS   MONTENEGRO            431240
#
#            NU_AMOSTRA TP_MOTIVO_COLETA TP_ABASTECIMENTO  \
# 0        213216000207           Rotina              SAC
# 417959   213216000207           Rotina              SAC
# 1464347  213216000207           Rotina              SAC
# 1809511  213216000207           Rotina              SAC
# 2350895  213216000207           Rotina              SAC
#
#         NU_SOLUCAO_ABASTECIMENTO NO_SOLUCAO_ABASTECIMENTO  ... NO_LOCAL  \
# 0                  C431240000008              SAC SOBRADO  ...      NaN
# 417959             C431240000008              SAC SOBRADO  ...      NaN
# 1464347            C431240000008              SAC SOBRADO  ...      NaN
# 1809511            C431240000008              SAC SOBRADO  ...      NaN
# 2350895            C431240000008              SAC SOBRADO  ...      NaN
#
#          NU_LATITUDE  NU_LONGITUDE                    PARAMETRO  \
# 0                NaN           NaN              Fluoreto (mg/L)
# 417959           NaN           NaN                Turbidez (uT)
# 1464347          NaN           NaN  Cloro residual livre (mg/L)
# 1809511          NaN           NaN            Coliformes totais
# 2350895          NaN           NaN             Escherichia coli
#
#         ANALISE_REALIZADA DT_ANALISE  LD  LQ RESULTADO PROVIDENCIA
# 0                     NaN        NaN NaN NaN      0,05         NaN
# 417959     EM_LABORATORIO        NaN NaN NaN       0,9         NaN
# 1464347          EM_CAMPO        NaN NaN NaN      1,01         NaN
# 1809511               NaN        NaN NaN NaN   AUSENTE         NaN
# 2350895               NaN        NaN NaN NaN   AUSENTE         NaN
#
# [5 rows x 34 columns]

# %%
amostras_por_municipio = (
    df_sisagua
    .groupby(['CO_MUNICIPIO_IBGE', 'NO_MUNICIPIO'])['NU_AMOSTRA']
    .nunique()
    .reset_index(name='QTDE_AMOSTRAS')
)
display(amostras_por_municipio)
display(amostras_por_municipio.shape)
display(amostras_por_municipio.info())
display(amostras_por_municipio.describe())
# Out:
#      CO_MUNICIPIO_IBGE           NO_MUNICIPIO  QTDE_AMOSTRAS
# 0               110001  ALTA FLORESTA D'OESTE             36
# 1               110002              ARIQUEMES            257
# 2               110003                 CABIXI             49
# 3               110004                 CACOAL            500
# 4               110005             CEREJEIRAS             22
# ...                ...                    ...            ...
# 5015            530027        JARDIM BOTANICO              1
# 5016            530028                 ITAPOA             10
# 5017            530029                   SCIA              1
# 5018            530030          VICENTE PIRES              1
# 5019            530031                 FERCAL              5
#
# [5020 rows x 3 columns]
# (5020, 3)
# <class 'pandas.DataFrame'>
# RangeIndex: 5020 entries, 0 to 5019
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CO_MUNICIPIO_IBGE  5020 non-null   str
#  1   NO_MUNICIPIO       5020 non-null   str
#  2   QTDE_AMOSTRAS      5020 non-null   int64
# dtypes: int64(1), str(2)
# memory usage: 204.7 KB
# None
#        QTDE_AMOSTRAS
# count    5020.000000
# mean      134.355179
# std       165.585152
# min         1.000000
# 25%        63.000000
# 50%        99.000000
# 75%       155.000000
# max      4366.000000

# %%
amostras_por_municipio[amostras_por_municipio['QTDE_AMOSTRAS'] == 4366]
# Out:
#    CO_MUNICIPIO_IBGE NO_MUNICIPIO  QTDE_AMOSTRAS
# 63            130260       MANAUS           4366

# %%
amostras_por_municipio[amostras_por_municipio['QTDE_AMOSTRAS'] == 1]
# Out:
#      CO_MUNICIPIO_IBGE             NO_MUNICIPIO  QTDE_AMOSTRAS
# 58              130140                 EIRUNEPE              1
# 151             150500           NOVA TIMBOTEUA              1
# 318             171884              SANDOLANDIA              1
# 348             210170             BARREIRINHAS              1
# 381             210860                 PINHEIRO              1
# 425             220170               BERTOLINIA              1
# 453             220323                  CURRAIS              1
# 497             220700                   OEIRAS              1
# 534             221035    SAO LOURENCO DO PIAUI              1
# 744             240260              CEARA-MIRIM              1
# 764             240490                     ITAU              1
# 774             240590                JOAO DIAS              1
# 808             241090                RIACHUELO              1
# 815             241190   SAO FRANCISCO DO OESTE              1
# 826             241360           SEVERIANO MELO              1
# 1483            290890         CORACAO DE MARIA              1
# 2460            316230         SAO JOAO DA MATA              1
# 2595            320100            BOA ESPERANCA              1
# 2653            320506  VENDA NOVA DO IMIGRANTE              1
# 2670            330070                CABO FRIO              1
# 3402            410150                ARAPONGAS              1
# 3426            410320              BOM SUCESSO              1
# 3434            410350               CALIFORNIA              1
# 3506            410850         GENERAL CARNEIRO              1
# 3638            411860            PAULA FREITAS              1
# 3698            412310             SANTA AMELIA              1
# 3743            412640                SERTANEJA              1
# 4669            510330                 COMODORO              1
# 5000            530012                      SIA              1
# 5004            530016                 LAGO SUL              1
# 5005            530017             RIACHO FUNDO              1
# 5006            530018               LAGO NORTE              1
# 5009            530021          RIACHO FUNDO II              1
# 5011            530023                   VARJAO              1
# 5015            530027          JARDIM BOTANICO              1
# 5017            530029                     SCIA              1
# 5018            530030            VICENTE PIRES              1

# %%
df_sisagua[df_sisagua['CO_MUNICIPIO_IBGE'] == '241360']
# Out:
#         NO_REGIAO SG_UF          NO_REGIONAL    NO_MUNICIPIO  \
# 2611316  NORDESTE    RN  6 REGIONAL DE SAUDE  SEVERIANO MELO
# 2611317  NORDESTE    RN  6 REGIONAL DE SAUDE  SEVERIANO MELO
#
#         CO_MUNICIPIO_IBGE NU_AMOSTRA TP_MOTIVO_COLETA TP_ABASTECIMENTO  \
# 2611316            241360        001           Rotina              SAA
# 2611317            241360        001           Rotina              SAA
#
#         NU_SOLUCAO_ABASTECIMENTO                NO_SOLUCAO_ABASTECIMENTO  ...  \
# 2611316            S241360000001  SISTEMA INTEGRADO APODI SEVERIANO MELO  ...
# 2611317            S241360000001  SISTEMA INTEGRADO APODI SEVERIANO MELO  ...
#
#                  NO_LOCAL  NU_LATITUDE  NU_LONGITUDE          PARAMETRO  \
# 2611316  UBS GENILDO MELO          NaN           NaN  Coliformes totais
# 2611317  UBS GENILDO MELO          NaN           NaN   Escherichia coli
#
#         ANALISE_REALIZADA DT_ANALISE  LD  LQ RESULTADO PROVIDENCIA
# 2611316               NaN        NaN NaN NaN   AUSENTE         NaN
# 2611317               NaN        NaN NaN NaN   AUSENTE         NaN
#
# [2 rows x 34 columns]

# %%
amostras_parametro_municipio = (df_sisagua
                                .groupby(['CO_MUNICIPIO_IBGE', 'NO_MUNICIPIO', 'PARAMETRO'])['NU_AMOSTRA']
                                .nunique()
                                .reset_index(name='QTDE_AMOSTRAS'))
display(amostras_parametro_municipio)
display(amostras_parametro_municipio.shape)
display(amostras_parametro_municipio.info())
display(amostras_parametro_municipio.describe())
# Out:
#       CO_MUNICIPIO_IBGE           NO_MUNICIPIO                    PARAMETRO  \
# 0                110001  ALTA FLORESTA D'OESTE     Bactérias Heterotróficas
# 1                110001  ALTA FLORESTA D'OESTE  Cloro residual livre (mg/L)
# 2                110001  ALTA FLORESTA D'OESTE            Coliformes totais
# 3                110001  ALTA FLORESTA D'OESTE             Escherichia coli
# 4                110001  ALTA FLORESTA D'OESTE                           pH
# ...                 ...                    ...                          ...
# 25356            530031                 FERCAL            Coliformes totais
# 25357            530031                 FERCAL            Cor Aparente (uH)
# 25358            530031                 FERCAL             Escherichia coli
# 25359            530031                 FERCAL                Turbidez (uT)
# 25360            530031                 FERCAL                           pH
#
#        QTDE_AMOSTRAS
# 0                  5
# 1                  6
# 2                 36
# 3                 36
# 4                 36
# ...              ...
# 25356              5
# 25357              5
# 25358              5
# 25359              5
# 25360              5
#
# [25361 rows x 4 columns]
# (25361, 4)
# <class 'pandas.DataFrame'>
# RangeIndex: 25361 entries, 0 to 25360
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CO_MUNICIPIO_IBGE  25361 non-null  str
#  1   NO_MUNICIPIO       25361 non-null  str
#  2   PARAMETRO          25361 non-null  str
#  3   QTDE_AMOSTRAS      25361 non-null  int64
# dtypes: int64(1), str(3)
# memory usage: 1.6 MB
# None
#        QTDE_AMOSTRAS
# count   25361.000000
# mean      114.231852
# std       151.485590
# min         1.000000
# 25%        53.000000
# 50%        86.000000
# 75%       132.000000
# max      4362.000000

# %%
amostras_parametro_municipio.to_excel("amostras_parametro_municipio.xlsx",index=False)

# %%
df_sisagua[df_sisagua['CO_MUNICIPIO_IBGE'] == '355030']
# Out:
#         NO_REGIAO SG_UF      NO_REGIONAL NO_MUNICIPIO CO_MUNICIPIO_IBGE  \
# 34861     SUDESTE    SP  GVS I - CAPITAL    SAO PAULO            355030
# 34862     SUDESTE    SP  GVS I - CAPITAL    SAO PAULO            355030
# 34863     SUDESTE    SP  GVS I - CAPITAL    SAO PAULO            355030
# 34864     SUDESTE    SP  GVS I - CAPITAL    SAO PAULO            355030
# 34865     SUDESTE    SP  GVS I - CAPITAL    SAO PAULO            355030
# ...           ...   ...              ...          ...               ...
# 2687954   SUDESTE    SP  GVS I - CAPITAL    SAO PAULO            355030
# 2687955   SUDESTE    SP  GVS I - CAPITAL    SAO PAULO            355030
# 2687956   SUDESTE    SP  GVS I - CAPITAL    SAO PAULO            355030
# 2687963   SUDESTE    SP  GVS I - CAPITAL    SAO PAULO            355030
# 2687965   SUDESTE    SP  GVS I - CAPITAL    SAO PAULO            355030
#
#            NU_AMOSTRA TP_MOTIVO_COLETA TP_ABASTECIMENTO  \
# 34861    210109001052           Rotina              SAA
# 34862    210109001051           Rotina              SAA
# 34863    210109001109           Rotina              SAA
# 34864    210109001109           Rotina              SAA
# 34865    210109000743           Rotina              SAA
# ...               ...              ...              ...
# 2687954  210109000522           Rotina              SAA
# 2687955  210109000184           Rotina              SAA
# 2687956  210109003143           Rotina              SAA
# 2687963  210109000713           Rotina              SAA
# 2687965  210109002794           Rotina              SAA
#
#         NU_SOLUCAO_ABASTECIMENTO NO_SOLUCAO_ABASTECIMENTO  ... NO_LOCAL  \
# 34861              S355030000001       SISTEMA CANTAREIRA  ...      NaN
# 34862              S355030000001       SISTEMA CANTAREIRA  ...      NaN
# 34863              S355030000001       SISTEMA CANTAREIRA  ...      NaN
# 34864              S355030000001       SISTEMA CANTAREIRA  ...      NaN
# 34865              S355030000001       SISTEMA CANTAREIRA  ...      NaN
# ...                          ...                      ...  ...      ...
# 2687954            S350660000005        SISTEMA RIO CLARO  ...      NaN
# 2687955            S350660000005        SISTEMA RIO CLARO  ...      NaN
# 2687956            S350660000005        SISTEMA RIO CLARO  ...      NaN
# 2687963            S350660000005        SISTEMA RIO CLARO  ...      NaN
# 2687965            S350660000005        SISTEMA RIO CLARO  ...      NaN
#
#          NU_LATITUDE  NU_LONGITUDE          PARAMETRO ANALISE_REALIZADA  \
# 34861            NaN           NaN    Fluoreto (mg/L)               NaN
# 34862            NaN           NaN      Turbidez (uT)    EM_LABORATORIO
# 34863            NaN           NaN      Turbidez (uT)    EM_LABORATORIO
# 34864            NaN           NaN                 pH               NaN
# 34865            NaN           NaN                 pH               NaN
# ...              ...           ...                ...               ...
# 2687954          NaN           NaN  Coliformes totais               NaN
# 2687955          NaN           NaN  Coliformes totais               NaN
# 2687956          NaN           NaN  Coliformes totais               NaN
# 2687963          NaN           NaN   Escherichia coli               NaN
# 2687965          NaN           NaN  Coliformes totais               NaN
#
#         DT_ANALISE  LD  LQ RESULTADO PROVIDENCIA
# 34861          NaN NaN NaN      0,63         NaN
# 34862          NaN NaN NaN      0,83         NaN
# 34863          NaN NaN NaN      1,24         NaN
# 34864          NaN NaN NaN      7,84         NaN
# 34865          NaN NaN NaN      8,73         NaN
# ...            ...  ..  ..       ...         ...
# 2687954        NaN NaN NaN   AUSENTE         NaN
# 2687955        NaN NaN NaN   AUSENTE         NaN
# 2687956        NaN NaN NaN   AUSENTE         NaN
# 2687963        NaN NaN NaN   AUSENTE         NaN
# 2687965        NaN NaN NaN   AUSENTE         NaN
#
# [24048 rows x 34 columns]

# %%
df_sisagua[df_sisagua['CO_MUNICIPIO_IBGE'] == '355030']['NU_AMOSTRA'].nunique()
# Out:
# 3593
