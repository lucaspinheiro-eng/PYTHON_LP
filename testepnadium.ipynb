# %%
pip install pnadium pandas numpy openpyxl matplotlib pyarrow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pnadium
import pandas as pd
import numpy as np
import openpyxl
import matplotlib.pyplot as plt
import pyarrow

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

dic = pnadium.anual.consulta_var(2024, 1, "v")
display(dic)
# Out:
#       Tamanho      Código                                          Descrição
# 2         4.0         Ano                                  Ano de referência
# 3         1.0   Trimestre                            Trimestre de referência
# 4         2.0          UF                               Unidade da Federação
# 31        2.0     Capital                               Município da Capital
# 58        2.0     RM_RIDE  Região Metropolitana e Região Administrativa I...
# 79        9.0         UPA               Unidade Primária de Amostragem (UPA)
# 80        7.0     Estrato                                                NaN
# 81        2.0       V1008                     Número de seleção do domicílio
# 82        2.0       V1014                                             Painel
# 83        1.0       V1022                              Situação do domicílio
# 85        1.0       V1023                                       Tipo de área
# ...

# %%
pnadc = pnadium.anual.download(2024,1,'v',colunas=['UF','S01014','S01008'])
# Out:
# Iniciou o download: Visita 1/2024 - aguarde.
# Download finalizado.
# Iniciou a criação do DataFrame Pandas: esta etapa pode demorar alguns minutos.
# Chunks processados e salvos.
# DataFrame criado.
#    UF        UPA V1008 V1014 V2003  S01008  S01014        COD_FAM  \
# 0  11  110000016    03    11    01     1.0       1  1100000160311
# 1  11  110000016    06    11    01     1.0       1  1100000160611
# 2  11  110000016    06    11    02     1.0       1  1100000160611
# 3  11  110000016    08    11    01     1.0       1  1100000160811
# 4  11  110000016    08    11    02     1.0       1  1100000160811
# 5  11  110000016    09    11    01     1.0       1  1100000160911
# 6  11  110000016    09    11    02     1.0       1  1100000160911
# 7  11  110000016    10    11    01     1.0       1  1100000161011
# 8  11  110000016    10    11    02     1.0       1  1100000161011
# 9  11  110000016    11    11    01     1.0       1  1100000161111
#
#         COD_PESSOA
# 0  110000016031101
# ...

# %%
display(pnadc.head(10))
display(pnadc.shape)
display(pnadc.describe())
display(pnadc.info())
# Out:
#    UF        UPA V1008 V1014 V2003  S01008  S01014        COD_FAM  \
# 0  11  110000016    03    11    01     1.0       1  1100000160311
# 1  11  110000016    06    11    01     1.0       1  1100000160611
# 2  11  110000016    06    11    02     1.0       1  1100000160611
# 3  11  110000016    08    11    01     1.0       1  1100000160811
# 4  11  110000016    08    11    02     1.0       1  1100000160811
# 5  11  110000016    09    11    01     1.0       1  1100000160911
# 6  11  110000016    09    11    02     1.0       1  1100000160911
# 7  11  110000016    10    11    01     1.0       1  1100000161011
# 8  11  110000016    10    11    02     1.0       1  1100000161011
# 9  11  110000016    11    11    01     1.0       1  1100000161111
#
#         COD_PESSOA
# 0  110000016031101
# 1  110000016061101
# 2  110000016061102
# 3  110000016081101
# 4  110000016081102
# 5  110000016091101
# 6  110000016091102
# 7  110000016101101
# 8  110000016101102
# 9  110000016111101
# (381815, 9)
# ...
